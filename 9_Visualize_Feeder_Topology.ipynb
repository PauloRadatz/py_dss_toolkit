# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloRadatz/py_dss_toolkit/blob/master/9_Visualize_Feeder_Topology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install py-dss-toolkit
# Out:
# Collecting py-dss-toolkit
#   Downloading py_dss_toolkit-0.8.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting py-dss-interface>=2.3.0 (from py-dss-toolkit)
#   Downloading py_dss_interface-2.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from py-dss-toolkit) (2.2.2)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from py-dss-toolkit) (3.10.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.12/dist-packages (from py-dss-toolkit) (5.24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->py-dss-toolkit) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->py-dss-toolkit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->py-dss-toolkit) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->py-dss-toolkit) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->py-dss-toolkit) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->py-dss-toolkit) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->py-dss-toolkit) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->py-dss-toolkit) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->py-dss-toolkit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->py-dss-toolkit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->py-dss-toolkit) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.10.0->py-dss-toolkit) (9.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->py-dss-toolkit) (1.17.0)
# Downloading py_dss_toolkit-0.8.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.3/119.3 kB 4.0 MB/s eta 0:00:00
# Downloading py_dss_interface-2.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 40.6 MB/s eta 0:00:00
# Installing collected packages: py-dss-interface, py-dss-toolkit
# Successfully installed py-dss-interface-2.3.0 py-dss-toolkit-0.8.0

# %%
# !git clone https://github.com/PauloRadatz/opendss-python-examples
# Out:
# Cloning into 'opendss-python-examples'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 31 (delta 3), reused 31 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 176.48 KiB | 2.85 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
dss_file_path = "/content/opendss-python-examples/feeder_models/EPRITestCircuits/ckt5/Master_ckt5.dss"

# %%
import os
import pathlib
import pandas as pd
import plotly.graph_objects as go

import py_dss_interface
from py_dss_toolkit import dss_tools

# %%
dss = py_dss_interface.DSS()
dss_tools.update_dss(dss)
dss.started
# Out:
# True

# %%
dss.text(f"compile [{dss_file_path}]")
dss.text(f"solve")
# Out:
# ''
