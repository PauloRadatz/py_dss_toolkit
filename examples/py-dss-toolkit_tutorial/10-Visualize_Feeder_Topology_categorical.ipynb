# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloRadatz/py_dss_toolkit/blob/master/examples/py-dss-toolkit_tutorial/10-Visualize_Feeder_Topology_categorical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Circuit Interactive View (Categorical)
#
# This notebook demonstrates how to visualize a distribution feeder circuit using the `py_dss_toolkit` package. We’ll compile an OpenDSS model, solve a power flow, and generate interactive circuit plots for categorical variables—while exploring practical customization options.
#
# **Contact:** paulo.radatz@gmail.com
#
# If you’d like a structured learning path:
# - **OpenDSS courses:** https://www.pauloradatz.me/opendss-courses
# - **Learn the basics of controlling OpenDSS via Python (py-dss-interface course):** https://www.pauloradatz.me/course-py-dss-interface

# %% [markdown]
# ## Install packages
#
# We’ll install `py-dss-toolkit`. During installation, `pip` will also install `py-dss-interface`, which is a required dependency.
#
# - **`py-dss-toolkit`**: utilities to run OpenDSS studies and generate high-level visualizations (including interactive circuit plots).
# - **`py-dss-interface`**: a Python package that controls **OpenDSS Powered by EPRI** directly from Python.

# %%
# !pip install py-dss-toolkit
# Out:
# Requirement already satisfied: py-dss-toolkit in C:\PauloRadatz\GitHub\py_dss_toolkit\src (0.10.0)
# Requirement already satisfied: py-dss-interface>=2.3.0 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from py-dss-toolkit) (2.3.0)
# Requirement already satisfied: pandas>=2.2 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from py-dss-toolkit) (3.0.1)
# Requirement already satisfied: matplotlib>=3.10 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from py-dss-toolkit) (3.10.8)
# Requirement already satisfied: plotly>=5.20 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from py-dss-toolkit) (6.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from matplotlib>=3.10->py-dss-toolkit) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from matplotlib>=3.10->py-dss-toolkit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from matplotlib>=3.10->py-dss-toolkit) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from matplotlib>=3.10->py-dss-toolkit) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from matplotlib>=3.10->py-dss-toolkit) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from matplotlib>=3.10->py-dss-toolkit) (24.2)
# Requirement already satisfied: pillow>=8 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from matplotlib>=3.10->py-dss-toolkit) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from matplotlib>=3.10->py-dss-toolkit) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from matplotlib>=3.10->py-dss-toolkit) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from pandas>=2.2->py-dss-toolkit) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from plotly>=5.20->py-dss-toolkit) (1.33.0)
# Requirement already satisfied: six>=1.5 in C:\PauloRadatz\GitHub\py_dss_toolkit\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10->py-dss-toolkit) (1.17.0)

# %% [markdown]
# ## Download the example feeder
#
# Next, we’ll clone the `opendss-python-examples` repository, which includes ready-to-run OpenDSS feeder models.
# We’ll use one of these feeders as the input circuit for the visualization examples in this notebook.

# %%
# !git clone https://github.com/PauloRadatz/opendss-python-examples
# Out:
# Cloning into 'opendss-python-examples'...

# %% [markdown]
# ## Define the DSS master file path
#
# Now we set the path to the **OpenDSS master file** (`Master_ckt5.dss`).
# This file is the entry point of the feeder model—it typically redirects to all the other DSS files (lines, loads, transformers, etc.) needed to compile the circuit.

# %%
dss_file_path = "/content/opendss-python-examples/feeder_models/EPRITestCircuits/ckt5/Master_ckt5.dss"

# %% [markdown]
# ## Imports
#
# We’ll use `py-dss-interface` together with `py-dss-toolkit`:
#
# - **`py_dss_interface`** provides a direct connection to the OpenDSS engine.
# - **`dss_tools`** (from `py_dss_toolkit`) builds on top of that connection to simplify common workflows—such as accessing models, retrieving results, and creating interactive visualizations.

# %%
import py_dss_interface
from py_dss_toolkit import dss_tools

# %% [markdown]
# ## Initialize OpenDSS and connect it to `dss_tools`
#
# Next, we create a DSS engine instance using `py_dss_interface` to initialize the simulation environment.
#
# Then we connect that same DSS instance to `dss_tools`, so all toolkit helper functions operate on the exact engine we just created.

# %%
dss = py_dss_interface.DSS()
dss_tools.update_dss(dss)
dss.started
# Out:
# True

# %% [markdown]
# ## Compile the model and solve a power flow
#
# Now we compile the OpenDSS master file and run a power flow solution:
#
# - **`compile`** loads the circuit and all referenced files (via `Redirect` commands). For more details, see **Module 2** of: https://www.pauloradatz.me/course-snapshot
# - **`solve`** runs the power flow so voltages, currents, and power flows are available for visualization and analysis.

# %%
dss.text(f"compile [{dss_file_path}]")
dss.text(f"solve")
# Out:
# 'You must create a new circuit object first: "new circuit.mycktname" to execute this command.'

# %% [markdown]
# ## Plot active power in the circuit
#
# Now we’ll create an interactive circuit plot using **phases** as the displayed parameter (3-phase, 2-phase, and 1-phase lines).

# %%
dss_tools.interactive_view.circuit_plot(parameter="phases", title="Phases")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dss_tools.interactive_view.circuit_plot(parameter="phases", title="Phases")
#
# File C:\PauloRadatz\GitHub\py_dss_toolkit\src\py_dss_toolkit\view\interactive_view\SnapShot\Circuit\Circuit.py:96, in Circuit.circuit_plot(self, parameter, title, xlabel, ylabel, width_3ph, width_2ph, width_1ph, dash_3ph, dash_2ph, dash_1ph, dash_oh, dash_ug, mark_buses, bus_markers, show_colorbar, warn_zero_coord_buses, show, save_file_path)
#      41 def circuit_plot(self,
#      42                  parameter: CircuitPlotParameter = "active power",
#      43                  title: Optional[str] = "Circuit Plot",
#    (...)     58                  show: bool = False,
#      59                  save_file_path: Optional[str] = None) -> go.Figure:
#      60     """
#      61     Create an interactive circuit plot.
#      62
#    (...)     94         go.Figure: The Plotly figure object.
#      95     """
# ---> 96     return self._circuit_plot.circuit_plot(
#      97         parameter=parameter,
#      98         title=title,
#      99         xlabel=xlabel,
#     100         ylabel=ylabel,
#     101         width_3ph=width_3ph,
#     102         width_2ph=width_2ph,
#     103         width_1ph=width_1ph,
#     104         dash_3ph=dash_3ph,
#     105         dash_2ph=dash_2ph,
#     106         dash_1ph=dash_1ph,
#     107         dash_oh=dash_oh,
#     108         dash_ug=dash_ug,
#     109         mark_buses=mark_buses,
#     110         bus_markers=bus_markers,
#     111         show_colorbar=show_colorbar,
#     112         warn_zero_coord_buses=warn_zero_coord_buses,
#     113         show=show,
#     114         save_file_path=save_file_path
#     115     )
#
# File C:\PauloRadatz\GitHub\py_dss_toolkit\src\py_dss_toolkit\view\interactive_view\SnapShot\Circuit\CircuitPlot.py:49, in CircuitPlot.circuit_plot(self, parameter, title, xlabel, ylabel, width_3ph, width_2ph, width_1ph, dash_3ph, dash_2ph, dash_1ph, dash_oh, dash_ug, mark_buses, bus_markers, show_colorbar, warn_zero_coord_buses, show, save_file_path)
#      46 else:
#      47     mode = 'lines'
# ---> 49 plot_data = self._prepare_plot_data(parameter, warn_zero_coord_buses=warn_zero_coord_buses)
#      50 settings = plot_data['settings']
#      51 results = plot_data['results']
#
# File C:\PauloRadatz\GitHub\py_dss_toolkit\src\py_dss_toolkit\view\interactive_view\SnapShot\Circuit\CircuitBase.py:378, in CircuitBase._prepare_plot_data(self, parameter, warn_zero_coord_buses)
#     371 def _prepare_plot_data(self, parameter: CircuitPlotParameter, warn_zero_coord_buses: bool = False):
#     372     """
#     373     Prepare common data for both circuit_plot and circuit_geoplot methods.
#     374
#     375     Returns:
#     376         dict: Contains all the data needed for plotting
#     377     """
# --> 378     line_df = self._model.lines_df.copy()
#     379     line_df['name'] = 'line.' + line_df['name']
#     380     settings, results, hovertemplate, numerical_plot = self._get_plot_settings(parameter, lines_df=line_df)
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %% [markdown]
# ## Two ways to customize `circuit_plot()`
#
# There are two main ways to change how the interactive circuit plot looks:
#
# 1. **Method parameters (most common)**
#    Pass options directly into `circuit_plot(...)`—like `title`, `width_2ph`, `width_1ph`, and others.
#    This is the approach you’ll use most of the time, and it’s why the most common settings are exposed as method parameters.
#
# 2. **Settings object**
#    For additional options that are not exposed as parameters, you can edit the settings object associated with the plot type.
#    For active power, that object is: `dss_tools.interactive_view.phases_settings`
#
# In the next cells, we’ll use both approaches so you can recognize when each one is more convenient.

# %%
dss_tools.interactive_view.phases_settings.legendgrouptitle_text = "Phases"
dss_tools.interactive_view.active_power_settings.color_map = {'4': ["4", "purple"], '3': ["3", "blue"], '2': ["2", "red"], '1': ["1", "green"]}
dss_tools.interactive_view.circuit_plot(parameter="phases")

# %% [markdown]
# ## Wrap-up
#
# You’ve now seen a complete workflow to visualize an OpenDSS feeder with `py-dss-toolkit`:
#
# - Install the packages and load an example feeder model
# - Compile and solve a power flow with OpenDSS
# - Create interactive circuit plots ("phases", "voltage violations", "thermal violations")
# - Customize plots using categorical variables **method parameters** and **settings objects**
# - Add **bus markers** to highlight locations of interest
#
# If you have questions, suggestions, or ideas for additional features/examples, feel free to reach out:
#
# **Contact:** paulo.radatz@gmail.com
#
# More learning resources:
# - **OpenDSS courses:** https://www.pauloradatz.me/opendss-courses
# - **Python + OpenDSS fundamentals (py-dss-interface course):** https://www.pauloradatz.me/course-py-dss-interface
