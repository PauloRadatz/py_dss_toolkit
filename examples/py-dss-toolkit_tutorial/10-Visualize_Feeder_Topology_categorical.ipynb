# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloRadatz/py_dss_toolkit/blob/master/examples/py-dss-toolkit_tutorial/10-Visualize_Feeder_Topology_categorical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Circuit Interactive View (Categorical)
#
# This notebook demonstrates how to visualize a distribution feeder circuit using the `py_dss_toolkit` package. We’ll compile an OpenDSS model, solve a power flow, and generate interactive circuit plots for categorical variables—while exploring practical customization options.
#
# **Contact:** paulo.radatz@gmail.com
#
# If you’d like a structured learning path:
# - **OpenDSS courses:** https://www.pauloradatz.me/opendss-courses
# - **Learn the basics of controlling OpenDSS via Python (py-dss-interface course):** https://www.pauloradatz.me/course-py-dss-interface

# %% [markdown]
# ## Install packages
#
# We’ll install `py-dss-toolkit`. During installation, `pip` will also install `py-dss-interface`, which is a required dependency.
#
# - **`py-dss-toolkit`**: utilities to run OpenDSS studies and generate high-level visualizations (including interactive circuit plots).
# - **`py-dss-interface`**: a Python package that controls **OpenDSS Powered by EPRI** directly from Python.

# %%
# !pip install py-dss-toolkit
# Out:
# Collecting py-dss-toolkit
#   Downloading py_dss_toolkit-0.10.0-py3-none-any.whl.metadata (9.7 kB)
# Collecting py-dss-interface>=2.3.0 (from py-dss-toolkit)
#   Downloading py_dss_interface-2.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.12/dist-packages (from py-dss-toolkit) (2.2.2)
# Requirement already satisfied: matplotlib>=3.10 in /usr/local/lib/python3.12/dist-packages (from py-dss-toolkit) (3.10.0)
# Requirement already satisfied: plotly>=5.20 in /usr/local/lib/python3.12/dist-packages (from py-dss-toolkit) (5.24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10->py-dss-toolkit) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10->py-dss-toolkit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10->py-dss-toolkit) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10->py-dss-toolkit) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10->py-dss-toolkit) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10->py-dss-toolkit) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10->py-dss-toolkit) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10->py-dss-toolkit) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10->py-dss-toolkit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->py-dss-toolkit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->py-dss-toolkit) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.20->py-dss-toolkit) (9.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.10->py-dss-toolkit) (1.17.0)
# Downloading py_dss_toolkit-0.10.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 3.6 MB/s eta 0:00:00
# Downloading py_dss_interface-2.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 26.6 MB/s eta 0:00:00
# Installing collected packages: py-dss-interface, py-dss-toolkit
# Successfully installed py-dss-interface-2.3.0 py-dss-toolkit-0.10.0

# %% [markdown]
# ## Download the example feeder
#
# Next, we’ll clone the `opendss-python-examples` repository, which includes ready-to-run OpenDSS feeder models.
# We’ll use one of these feeders as the input circuit for the visualization examples in this notebook.

# %%
# !git clone https://github.com/PauloRadatz/opendss-python-examples
# Out:
# Cloning into 'opendss-python-examples'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 31 (delta 3), reused 31 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 176.48 KiB | 4.77 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %% [markdown]
# ## Define the DSS master file path
#
# Now we set the path to the **OpenDSS master file** (`Master_ckt5.dss`).
# This file is the entry point of the feeder model—it typically redirects to all the other DSS files (lines, loads, transformers, etc.) needed to compile the circuit.

# %%
dss_file_path = "/content/opendss-python-examples/feeder_models/EPRITestCircuits/ckt5/Master_ckt5.dss"

# %% [markdown]
# ## Imports
#
# We’ll use `py-dss-interface` together with `py-dss-toolkit`:
#
# - **`py_dss_interface`** provides a direct connection to the OpenDSS engine.
# - **`dss_tools`** (from `py_dss_toolkit`) builds on top of that connection to simplify common workflows—such as accessing models, retrieving results, and creating interactive visualizations.

# %%
import py_dss_interface
from py_dss_toolkit import dss_tools

# %% [markdown]
# ## Initialize OpenDSS and connect it to `dss_tools`
#
# Next, we create a DSS engine instance using `py_dss_interface` to initialize the simulation environment.
#
# Then we connect that same DSS instance to `dss_tools`, so all toolkit helper functions operate on the exact engine we just created.

# %%
dss = py_dss_interface.DSS()
dss_tools.update_dss(dss)
dss.started
# Out:
# True

# %% [markdown]
# ## Compile the model and solve a power flow
#
# Now we compile the OpenDSS master file and run a power flow solution:
#
# - **`compile`** loads the circuit and all referenced files (via `Redirect` commands). For more details, see **Module 2** of: https://www.pauloradatz.me/course-snapshot
# - **`solve`** runs the power flow so voltages, currents, and power flows are available for visualization and analysis.

# %%
dss.text(f"compile [{dss_file_path}]")
dss.text(f"solve")
# Out:
# ''

# %% [markdown]
# ## Plot active power in the circuit
#
# Now we’ll create an interactive circuit plot using **phases** as the displayed parameter (3-phase, 2-phase, and 1-phase lines).

# %%
dss_tools.interactive_view.circuit_plot(parameter="phases", title="Phases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8cc5ac94-dcf1-47d5-a870-59ef5a35bd20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cc5ac94-dcf1-47d5-a870-59ef5a35bd20")) {                    Plotly.newPlot(                        "8cc5ac94-dcf1-47d5-a870-59ef5a35bd20",                        [{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Line Phases"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"3-phases","showlegend":true,"x":[2237327.87,2237327.87],"y":[286213.17,286213.17],"type":"scatter"},{"customdata":[["line.mdv201_connector","_mdv_sub_1_lsb","mdv201","3"],["line.mdv201_connector","_mdv_sub_1_lsb","mdv201","3"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2237327.87],"y":[286213.17],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Line Phases"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":true,"x":[2228377.5,2228278.03],"y":[288378.78,288139.55],"type":"scatter"},{"customdata":[["line.mdv201_hn_1_275_a94744","94743","94744","1"],["line.mdv201_hn_1_275_a94744","94743","94744","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"green","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2228327.7649999997],"y":[288259.16500000004],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Line Phases"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":false,"x":[2237499.06,2237604.72],"y":[291025.7,290933.76],"type":"scatter"},{"customdata":[["line.mdv201_hn_2_466_c62235","62244","62235","1"],["line.mdv201_hn_2_466_c62235","62244","62235","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"green","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2237551.89],"y":[290979.73],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Line Phases"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":false,"x":[2235124.93,2234810.38],"y":[297129.27,296997.41],"type":"scatter"},{"customdata":[["line.mdv201_da_8_780_a1144234","1144235","1144234","1"],["line.mdv201_da_8_780_a1144234","1144235","1144234","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"green","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2234967.6550000003],"y":[297063.33999999997],"type":"s ...

# %% [markdown]
# ## Two ways to customize `circuit_plot()`
#
# There are two main ways to change how the interactive circuit plot looks:
#
# 1. **Method parameters (most common)**
#    Pass options directly into `circuit_plot(...)`—like `title`, `width_2ph`, `width_1ph`, and others.
#    This is the approach you’ll use most of the time, and it’s why the most common settings are exposed as method parameters.
#
# 2. **Settings object**
#    For additional options that are not exposed as parameters, you can edit the settings object associated with the plot type.
#    For active power, that object is: `dss_tools.interactive_view.phases_settings`
#
# In the next cells, we’ll use both approaches so you can recognize when each one is more convenient.

# %%
dss_tools.interactive_view.phases_settings.legendgrouptitle_text = "Phases"
dss_tools.interactive_view.active_power_settings.color_map = {'4': ["4", "purple"], '3': ["3", "blue"], '2': ["2", "red"], '1': ["1", "green"]}
dss_tools.interactive_view.circuit_plot(parameter="phases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="abf202f6-843c-4c78-a3cb-edcb7b293d86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abf202f6-843c-4c78-a3cb-edcb7b293d86")) {                    Plotly.newPlot(                        "abf202f6-843c-4c78-a3cb-edcb7b293d86",                        [{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Phases"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"3-phases","showlegend":true,"x":[2237327.87,2237327.87],"y":[286213.17,286213.17],"type":"scatter"},{"customdata":[["line.mdv201_connector","_mdv_sub_1_lsb","mdv201","3"],["line.mdv201_connector","_mdv_sub_1_lsb","mdv201","3"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2237327.87],"y":[286213.17],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Phases"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":true,"x":[2228377.5,2228278.03],"y":[288378.78,288139.55],"type":"scatter"},{"customdata":[["line.mdv201_hn_1_275_a94744","94743","94744","1"],["line.mdv201_hn_1_275_a94744","94743","94744","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"green","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2228327.7649999997],"y":[288259.16500000004],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Phases"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":false,"x":[2237499.06,2237604.72],"y":[291025.7,290933.76],"type":"scatter"},{"customdata":[["line.mdv201_hn_2_466_c62235","62244","62235","1"],["line.mdv201_hn_2_466_c62235","62244","62235","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"green","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2237551.89],"y":[290979.73],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Phases"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":false,"x":[2235124.93,2234810.38],"y":[297129.27,296997.41],"type":"scatter"},{"customdata":[["line.mdv201_da_8_780_a1144234","1144235","1144234","1"],["line.mdv201_da_8_780_a1144234","1144235","1144234","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"green","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2234967.6550000003],"y":[297063.33999999997],"type":"scatter"},{"hoverinfo ...

# %% [markdown]
# ## Categorical plots: voltage and thermal violations
#
# So far, we used categorical plotting to visualize **phases**. Next, we’ll use the same idea to highlight **operational issues** directly on the circuit map.
#
# We’ll cover two common categories:
#
# - **Voltage violations**: identify locations where bus voltages are outside the acceptable range (typically **undervoltage** and **overvoltage**, based on per-unit limits).
# - **Thermal (ampacity) violations**: identify lines/transformers operating above their current rating (i.e., **overloaded** elements).
#
# The key difference from numerical plots is that here we are not coloring by a continuous value (like kW or pu). Instead, each segment (or element) is assigned to a **category** (e.g., *Normal*, *Undervoltage*, *Overvoltage*, *Overloaded*), which makes it much easier to scan the feeder and immediately spot problem areas.

# %%
dss_tools.results.set_violation_voltage_ln_limits( v_min_pu=0.98, v_max_pu=1.02)
dss_tools.interactive_view.circuit_plot(parameter="voltage violations")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2fe84b40-8a3d-4dbd-ac75-db6c38c5d645" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fe84b40-8a3d-4dbd-ac75-db6c38c5d645")) {                    Plotly.newPlot(                        "2fe84b40-8a3d-4dbd-ac75-db6c38c5d645",                        [{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Voltage Violations"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"Normal","showlegend":true,"x":[2237327.87,2237327.87],"y":[286213.17,286213.17],"type":"scatter"},{"customdata":[["line.mdv201_connector","_mdv_sub_1_lsb","mdv201","0"],["line.mdv201_connector","_mdv_sub_1_lsb","mdv201","0"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2237327.87],"y":[286213.17],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Voltage Violations"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"Normal","showlegend":false,"x":[2228377.5,2228278.03],"y":[288378.78,288139.55],"type":"scatter"},{"customdata":[["line.mdv201_hn_1_275_a94744","94743","94744","0"],["line.mdv201_hn_1_275_a94744","94743","94744","0"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2228327.7649999997],"y":[288259.16500000004],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Voltage Violations"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"Normal","showlegend":false,"x":[2237499.06,2237604.72],"y":[291025.7,290933.76],"type":"scatter"},{"customdata":[["line.mdv201_hn_2_466_c62235","62244","62235","0"],["line.mdv201_hn_2_466_c62235","62244","62235","0"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2237551.89],"y":[290979.73],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Voltage Violations"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"Normal","showlegend":false,"x":[2235124.93,2234810.38],"y":[297129.27,296997.41],"type":"scatter"},{"customdata":[["line.mdv201_da_8_780_a1144234","1144235","1144234","0"],["line.mdv201_da_8_780_a1144234","1144235","1144234","0"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2234967.6550000003],"y":[297063.33999999997],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Voltage Violations"},"line":{"color":"purple","dash":"solid","width":3},"mode":"lines+markers","name":"Under Voltage","showlegend":true,"x":[2236061.43,2236194.71],"y":[292711.95,2926 ...

# %%
dss_tools.results.set_violation_current_limit_type(limit_type="emerg_amps")
dss_tools.results.set_currents_loading_threshold_percent(threshold_percent=20)
dss_tools.interactive_view.circuit_plot(parameter="thermal violations")
# Out:
# /usr/local/lib/python3.12/dist-packages/py_dss_toolkit/results/SnapShot/CurrentsViolations.py:22: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[True False True True True True True True True False True True True True
#  True True True True True True True False True True True True False False
#  True True True True True True False True True True True True False False
#  True True False False True True True True True False True True True True
#  False True False True True False True True True True True False True
#  False False True False False False True True True False True True True
#  True True False False True True False True True True True True True True
#  False True True True True False True True False False True True True True
#  False False False True True True True True True True True True True True
#  True True False False True False False True False True False True True
#  True True True True False True False True True False False True True
#  False True True False False True True False True True True True True
#  False True True True True True True True True True False True True False
#  True True True True False True True True False False True True False
#  False False False False True True True True True False True True True
#  True False True False True False True True True True False False True
#  True True True True True False False False True True True True True True
#  False True False True False True True True True True True True False True
#  False False True True False True True True False True True True True
#  False True True True False True True False False True True True True True
#  True True True True True False True True False True True False True True
#  True False True True True True False False True True True True True False
#  False False False False False True False True False True True True True
#  True True False False True True True True False True False True True True
#  False True True True True False False False False True True True True
#  False False True True True False True True False True True True True
#  False True True True True True True False True True True False False True
#  True True False False False False True True True True True True True
#  False True True False True True True True True True True True True True
#  True True True True True True True True True True False True True False
#  True True True True True False True True True True False True False True
#  False False False True True False True True True True True True True True
#  True True True True False True True True False False True True True True
#  True True True True True True False False False True True True True True
#  True True False True True True True False False True True True True True
#  True False True True True True True True True False True True True True
#  False True True True True True True False True True True False True True
#  False False False False True True False True True True True True True
#  True True True True True False True True True True False True True False
#  True False False True True True True True False False True True True True
#  True True True True True True True False False False True True True True
#  False True True False True True True True False False True True False
#  True True True False False True True True True True False False False
#  False True True True True True]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="83b6fe6d-f143-43ce-a624-4684eb3aa15a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83b6fe6d-f143-43ce-a624-4684eb3aa15a")) {                    Plotly.newPlot(                        "83b6fe6d-f143-43ce-a624-4684eb3aa15a",                        [{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Thermal Violations"},"line":{"color":"red","dash":"solid","width":3},"mode":"lines+markers","name":"Abnormal","showlegend":true,"x":[2237327.87,2237327.87],"y":[286213.17,286213.17],"type":"scatter"},{"customdata":[["line.mdv201_connector","_mdv_sub_1_lsb","mdv201","1"],["line.mdv201_connector","_mdv_sub_1_lsb","mdv201","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"red","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2237327.87],"y":[286213.17],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Thermal Violations"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"Normal","showlegend":true,"x":[2228377.5,2228278.03],"y":[288378.78,288139.55],"type":"scatter"},{"customdata":[["line.mdv201_hn_1_275_a94744","94743","94744","0"],["line.mdv201_hn_1_275_a94744","94743","94744","0"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2228327.7649999997],"y":[288259.16500000004],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Thermal Violations"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"Normal","showlegend":false,"x":[2237499.06,2237604.72],"y":[291025.7,290933.76],"type":"scatter"},{"customdata":[["line.mdv201_hn_2_466_c62235","62244","62235","0"],["line.mdv201_hn_2_466_c62235","62244","62235","0"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2237551.89],"y":[290979.73],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Thermal Violations"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"Normal","showlegend":false,"x":[2235124.93,2234810.38],"y":[297129.27,296997.41],"type":"scatter"},{"customdata":[["line.mdv201_da_8_780_a1144234","1144235","1144234","0"],["line.mdv201_da_8_780_a1144234","1144235","1144234","0"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[2234967.6550000003],"y":[297063.33999999997],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Thermal Violations"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"Normal","showlegend":false,"x":[2236061.43,2236194.71],"y":[292711.95,292623.6],"ty ...

# %% [markdown]
# ## Wrap-up
#
# You’ve now seen a complete workflow to visualize an OpenDSS feeder with `py-dss-toolkit`:
#
# - Install the packages and load an example feeder model
# - Compile and solve a power flow with OpenDSS
# - Create interactive circuit plots ("phases", "voltage violations", "thermal violations")
# - Customize plots using categorical variables **method parameters** and **settings objects**
# - Add **bus markers** to highlight locations of interest
#
# If you have questions, suggestions, or ideas for additional features/examples, feel free to reach out:
#
# **Contact:** paulo.radatz@gmail.com
#
# More learning resources:
# - **OpenDSS courses:** https://www.pauloradatz.me/opendss-courses
# - **Python + OpenDSS fundamentals (py-dss-interface course):** https://www.pauloradatz.me/course-py-dss-interface
